# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as BS
import csv
import json
import time
import pandas as pd

url = 'https://betscsgo.gg/history/'
driver = webdriver.Chrome('C:\Projects_Learnpython\chromedriver')
driver.get(url)

# %%
# Парсинг со всех страничек сайта истории

left_team_money_all = [] # Список с деньгами, поставленными на левую команду
right_team_money_all = [] # Список с деньгами, поставленными на правую команду
winning_team_past = [] # Список с победителями прошедших матчпей
dictionary_past_results = [] # Список словарей с результатами работы программы
hyps = [] # Список гипотез

for page_number in range(1, 99):
    url = 'https://betscsgo.gg/history/{}/'.format(page_number)
    driver.get(url)
    time.sleep(15)
    soup = BS(driver.page_source, 'html.parser')
    left_teams = soup.findAll("div", class_="bet-team__name sys-t1name") # Название команды, написанной слева
    right_teams = soup.findAll("div", class_="bet-team__name sys-t2name") # Название команды, написанной справа
    left_team_money = soup.findAll("div",\
    class_ = "bet-button__content-main bet-currency bet-currency_RUB sys-stat-abs-1") # Количество поставленных денег на первую команду
    for lmoney in left_team_money: # Проверка полной длины списка
        left_team_money_all.append(lmoney.text.replace(' ', '')) 
    right_team_money = soup.findAll("div",\
    class_ = "bet-button__content-main bet-currency bet-currency_RUB sys-stat-abs-2") # Количество поставленных денег на вторую команду
    for rmoney in right_team_money: # Наполнение списка
        right_team_money_all.append(rmoney.text.replace(' ', '')) 
    scores = soup.findAll("div",\
    class_ ="bet-match__additional-info-item bet-match__additional-info-item_result sys-time-fixed") # Найти счет матча
    winning_team_find = soup.select("div.bet-item")
    for wteam in winning_team_find:
        if "bet-winner-left" in wteam["class"]:
            winning_team_past.append("Первая команда") # Список победивших команд
        elif "bet-winner-right" in wteam["class"]:
            winning_team_past.append("Вторая команда")
        elif "bet-rescheduled" in wteam["class"]:
            winning_team_past.append("Матч перенесен")
        elif "bet-canceled" in wteam["class"]:
            winning_team_past.append("Матч отменен")
    # Проверка гипотезы
    for compare in range(len(left_team_money_all)): #перебираем элементы списка (в пределах длины первого списка)
        if ((int(left_team_money_all[compare]) > int(right_team_money_all[compare]))\
        and winning_team_past[compare] == "Первая команда")\
        or ((int(left_team_money_all[compare]) < int(right_team_money_all[compare]))\
        and winning_team_past[compare] == "Вторая команда"):
            hyps.append("Гипотеза верна")
        elif ((int(left_team_money_all[compare]) < int(right_team_money_all[compare]))\
        and winning_team_past[compare] == "Первая команда")\
        or ((int(left_team_money_all[compare]) > int(right_team_money_all[compare]))\
        and winning_team_past[compare] == "Вторая команда"):
            hyps.append("Гипотеза не верна")
        else:
            hyps.append("Гипотеза не проверялась")
    for ptf in range(len(left_teams)): 
        dictionary_past_results.append({"Left_team_title": left_teams[ptf].text,\
                                        "Moneybet_for_left_team": left_team_money[ptf].text.replace(' ', ''),\
                                        "Score": scores[ptf].text,\
                                        "Right_team_title": right_teams[ptf].text,\
                                        "Moneybet_for_right_team": right_team_money[ptf].text.replace(' ', ''),\
                                       "Winning_team_match_result": winning_team_past[ptf],\
                                       "Hypothesis": hyps[ptf],})

# Формула, которая считает процент верных и неверных гипотез через count ()      
model_success_percent = int(100 * hyps.count("Гипотеза верна") / (hyps.count("Гипотеза верна") + hyps.count("Гипотеза не верна")))
model_not_success_percent = int(100 * hyps.count("Гипотеза не верна") / (hyps.count("Гипотеза верна") + hyps.count("Гипотеза не верна")))

hyps_result = "Случаев выполнения гипотезы: {}, что составляет {}%; случаев, когда гипотеза была не выполнена {},что составляет {}%".format(hyps.count("Гипотеза верна"), model_success_percent, hyps.count("Гипотеза не верна"), model_not_success_percent)


# Создание csv файла с прошедшими матчами
with open('C:\Projects_Learnpython\past_CSmatchs.csv', 'w', newline='', encoding='utf-8') as ptcsv:
    ptfields = ["Left_team_title", "Moneybet_for_left_team",\
                "Score",\
                "Right_team_title", "Moneybet_for_right_team", "Winning_team_match_result",\
                "Hypothesis"]
    writer_past_matchs = csv.DictWriter(ptcsv, ptfields, delimiter=';')
    writer_past_matchs.writeheader()
    for row_past_matchs in dictionary_past_results:
        writer_past_matchs.writerow(row_past_matchs)

# Создание json файла с текущими матчами
with open ('C:\Projects_Learnpython\past_CSmatchs.json', 'w') as pts:
    json.dump("Результаты прошедших матчей: {}".format(dictionary_past_results), pts, ensure_ascii=False, sort_keys=True)
    json.dump("Результаты проверки гипотезы: {}".format(hyps_result), pts, ensure_ascii=False, sort_keys=True)

# Принты для проверки правильности работы программы
print(len(left_teams))
print(len(right_teams))    
print(len(left_team_money))
print(len(right_team_money))
print(dictionary_past_results)
print(len(left_team_money_all))
print(len(right_team_money_all))
print(len(winning_team_past))
print(len(dictionary_past_results))

# %%
# Парсинг текущих событий

url_matchs = 'https://betscsgo.gg/'
driver.get(url_matchs)
time.sleep(15)
soup = BS(driver.page_source, 'html.parser')
left_teams = soup.findAll("div", class_="bet-team__name sys-t1name") # Название команды, написанной слева
right_teams = soup.findAll("div", class_="bet-team__name sys-t2name") # Название команды, написанной справа
left_team_money = soup.findAll("div",\
class_ = "bet-button__content-main bet-currency bet-currency_RUB sys-stat-abs-1") 
# Количество поставленных денег на первую команду
right_team_money = soup.findAll("div",\
class_ = "bet-button__content-main bet-currency bet-currency_RUB sys-stat-abs-2")
# Количество поставленных денег на вторую команду
koef_left = soup.findAll("div",\
class_ ="bet-button__content-more-item bet-button__content-more-item_coeff sys-stat-koef-1") # Коэффициент на первую команду
koef_right = soup.findAll("div",\
class_="bet-button__content-more-item bet-button__content-more-item_coeff sys-stat-koef-2") # Коэффициент на вторую команду
win_proc_left = soup.findAll("div",\
class_ ="bet-button__content-more-item bet-button__content-more-item_percent sys-stat-proc-1") # Найти счет матча
win_proc_right = soup.findAll("div",\
class_ ="bet-button__content-more-item bet-button__content-more-item_percent sys-stat-proc-2") 
time_before_match = soup.findAll("div",\
class_=["bet-match__additional-info-item bet-match__additional-info-item_timer sys-time-left",\
"bet-match__additional-info-item  sys-time-fixed"]) # Время до начала матчей

dictionary_present_results = [] # Создание списка словарей

for prf in range(len(left_teams)):
    dictionary_present_results.append({"Left_team_title": left_teams[prf].text,\
                                       "Left_team_coefficients": koef_left[prf].text,\
                                       "Moneybet_for_left_team": left_team_money[prf].text.replace(' ', ''),\
                                       "Left_team_win_percent": win_proc_left[prf].text,\
                                       "Time_before_match": time_before_match[prf].text,\
                                       "Right_team_title": right_teams[prf].text,\
                                       "Right_team_coefficients": koef_right[prf].text,\
                                       "Moneybet_for_right_team": right_team_money[prf].text.replace(' ', ''),\
                                       "Right_team_win_percent": win_proc_right[prf].text})

# Создание csv файла с текущими матчами 
with open ('C:\Projects_Learnpython\present_CSmatchs.csv', 'w', newline='', encoding='utf-8') as prcsv:
    prfields = ["Left_team_title", "Left_team_coefficients", "Moneybet_for_left_team", "Left_team_win_percent",\
              "Time_before_match",\
              "Right_team_title", "Right_team_coefficients", "Moneybet_for_right_team", "Right_team_win_percent"]
    writer_present_matchs = csv.DictWriter(prcsv, prfields, delimiter=';')
    writer_present_matchs.writeheader()
    for row_present_matchs in dictionary_present_results:
        writer_present_matchs.writerow(row_present_matchs)

# Создание json файла с текущими матчами 
with open('C:\Projects_Learnpython\present_CSmatchs.json', 'w') as prs:
    json.dump("Текущие результаты матчей: {}".format(dictionary_present_results), prs, ensure_ascii=False, sort_keys=True)

# Принты для проверки правильности работы программы
print(len(left_teams))
print(len(right_teams))
print(len(left_team_money))
print(len(right_team_money))
print(len(koef_left))
print(len(koef_right))
print(len(win_proc_left))
print(len(win_proc_right))
print(len(time_before_match))
print(dictionary_present_results)
# Out:
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# [{'Left_team_title': ' 13 FURIA ', 'Left_team_coefficients': 'x1.08', 'Moneybet_for_left_team': '346637', 'Left_team_win_percent': '92%', 'Time_before_match': '1ч 46м', 'Right_team_title': ' Sharks 58 ', 'Right_team_coefficients': 'x10.82', 'Moneybet_for_right_team': '31768', 'Right_team_win_percent': '8%'}, {'Left_team_title': ' 128 Ignis ', 'Left_team_coefficients': 'x1.69', 'Moneybet_for_left_team': '110', 'Left_team_win_percent': '57%', 'Time_before_match': '3ч 46м', 'Right_team_title': ' Absolute null ', 'Right_team_coefficients': 'x2.18', 'Moneybet_for_right_team': '84', 'Right_team_win_percent': '43%'}, {'Left_team_title': ' 7 NRG ', 'Left_team_coefficients': 'x1.22', 'Moneybet_for_left_team': '92534', 'Left_team_win_percent': '80%', 'Time_before_match': '4ч 46м', 'Right_team_title': ' INTZ 45 ', 'Right_team_coefficients': 'x4.66', 'Moneybet_for_right_team': '22726', 'Right_team_win_percent': '20%'}, {'Left_team_title': ' null FATE ', 'Left_team_coefficients': 'x1.04', 'Moneybet_for_left_team': '1611', 'Left_team_win_percent': '96%', 'Time_before_match': '5ч 46м', 'Right_team_title': ' HEADSHOTBG null ', 'Right_team_coefficients': 'x21.07', 'Moneybet_for_right_team': '72', 'Right_team_win_percent': '4%'}, {'Left_team_title': ' 48 Epsilon ', 'Left_team_coefficients': 'x1.70', 'Moneybet_for_left_team': '734', 'Left_team_win_percent': '56%', 'Time_before_match': '6ч 46м', 'Right_team_title': ' Unicorns of Love 70 ', 'Right_team_coefficients': 'x2.15', 'Moneybet_for_right_team': '575', 'Right_team_win_percent': '44%'}, {'Left_team_title': ' 12 CR4ZY ', 'Left_team_coefficients': 'x1.50', 'Moneybet_for_left_team': '35348', 'Left_team_win_percent': '64%', 'Time_before_match': '7ч 46м', 'Right_team_title': ' Fnatic 8 ', 'Right_team_coefficients': 'x2.63', 'Moneybet_for_right_team': '19488', 'Right_team_win_percent': '36%'}, {'Left_team_title': ' 54 ALTERNATE aTTaX ', 'Left_team_coefficients': 'x36.30', 'Moneybet_for_left_team': '8', 'Left_team_win_percent': '2%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' AVANGAR 19 ', 'Right_team_coefficients': 'x1.02', 'Moneybet_for_right_team': '314', 'Right_team_win_percent': '98%'}, {'Left_team_title': ' 32 Tricked ', 'Left_team_coefficients': 'x6.22', 'Moneybet_for_left_team': '260', 'Left_team_win_percent': '15%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' Nemiga 42 ', 'Right_team_coefficients': 'x1.16', 'Moneybet_for_right_team': '1511', 'Right_team_win_percent': '85%'}, {'Left_team_title': ' 49 HAVU ', 'Left_team_coefficients': 'x1.00', 'Moneybet_for_left_team': '1644', 'Left_team_win_percent': '100%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' Fierce 87 ', 'Right_team_coefficients': '', 'Moneybet_for_right_team': '0', 'Right_team_win_percent': '0%'}, {'Left_team_title': ' 65 Izako Boars ', 'Left_team_coefficients': 'x1.07', 'Moneybet_for_left_team': '134', 'Left_team_win_percent': '93%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' Defusekids null ', 'Right_team_coefficients': 'x13.10', 'Moneybet_for_right_team': '10', 'Right_team_win_percent': '7%'}, {'Left_team_title': ' 63 expert ', 'Left_team_coefficients': 'x87.27', 'Moneybet_for_left_team': '17', 'Left_team_win_percent': '1%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' LDLC 64 ', 'Right_team_coefficients': 'x1.01', 'Moneybet_for_right_team': '1629', 'Right_team_win_percent': '99%'}, {'Left_team_title': ' 61 SJ Gaming ', 'Left_team_coefficients': 'x1.04', 'Moneybet_for_left_team': '126', 'Left_team_win_percent': '96%', 'Time_before_match': '10ч 16м', 'Right_team_title': ' BlueJays null ', 'Right_team_coefficients': 'x23.76', 'Moneybet_for_right_team': '5', 'Right_team_win_percent': '4%'}, {'Left_team_title': ' 88 Heretics ', 'Left_team_coefficients': 'x7.19', 'Moneybet_for_left_team': '21', 'Left_team_win_percent': '13%', 'Time_before_match': '10ч 46м', 'Right_team_title': ' Copenhagen Flames 74 ', 'Right_team_coefficients': 'x1.13', 'Moneybet_for_right_team': '144', 'Right_tea ...

# %%
import pandas as pd
pastmatchs = pd.read_csv('C:\Projects_Learnpython\past_CSmatchs.csv', sep=';')
presentmatchs = pd.read_csv('C:\Projects_Learnpython\present_CSmatchs.csv', sep=';')

# %%
pastmatchs
# Out:
#                Left_team_title  Moneybet_for_left_team  \
# 0       124 absolute mad lads                     1954
# 1                 null mythic                     4870
# 2             null Big Frames                     6133
# 3          null Thunder Logic                    10459
# 4                  4 Vitality                  1082010
# 5                  null Fanta                     3307
# 6                   77 DETONA                    50145
# 7          54 ALTERNATE aTTaX                    12458
# 8                   63 expert                     8395
# 9              65 Izako Boars                     6638
# 10                      10 G2                  2317592
# 11                 null EXILE                     8602
# 12                100 Goliath                    12060
# 13                  42 Nemiga                    10644
# 14        70 Unicorns of Love                    33371
# 15                  87 Fierce                    19122
# 16                    64 LDLC                     6019
# 17                 19 AVANGAR                    85964
# 18                   8 Fnatic                   985254
# 19                 4 Vitality                   333570
# 20                  16 Heroic                   348630
# 21                   12 CR4ZY                   946614
# 22               61 SJ Gaming                    99780
# 23                88 Heretics                    47396
# 24                    45 INTZ                   897551
# 25                 null PC419                     4967
# 26                  null DINQ                      465
# 27                      7 NRG                  1292197
# 28           137 Team Reapers                    28508
# 29                    44 EnVy                   229224
# ...                        ...                     ...
# 2844                null ViCi                   463139
# 2845               68 BOOT-dS                   192550
# 2846                77 DETONA                    29694
# 2847              null Denial                   344503
# 2848                  129 W7M                    50068
# 2849               29 eUnited                    54859
# 2850               1 Astralis                  2035974
# 2851                   6 Ence                   517631
# 2852                58 Sharks                    95957
# 2853            36 Luminosity                      181
# 2854              null Denial                      209
# 2855                   26 coL                    67538
# 2856              null Denial                    80055
# 2857                   6 Ence                   698020
# 2858                  15 mibr                  1040116
# 2859               1 Astralis                  1244653
# 2860               32 Tricked                    86933
# 2861               null Apeks                     9458
# 2862                  129 W7M                    14159
# 2863                  15 mibr                   455233
# 2864                   6 Ence                  1376921
# 2865               1 Astralis                  1362670
# 2866                 null S&P                      905
# 2867   null Imperial (Brazil)                    31805
# 2868      null Runtime (OwmS)                    57222
# 2869       54 ALTERNATE aTTaX                    63092
# 2870                 59 Syman                    73934
# 2871                   6 Ence                   928305
# 2872                 2 Liquid                   868915
# 2873               1 Astralis                  1076044
#
#                                                 Score  \
# 0                                            2 : 1
# 1                                            2 : 0
# 2                                            2 : 0
# 3                                            2 : 0
# 4                                            2 : 1
# 5                                            0 : 2
# 6        отменен
# 7                                            2 : 1
# 8                                            1 : 2
# 9                                            1 : 2
# 10                                           1 : 2
# 11                                           0 : 2
# 12                                           2 : 1
# 13                                           2 : 0
# 14                                           2 : 1
# 15                                           0 : 2
# 16                                           0 : 2
# 17                                           2 : 0
# 18                                           0 : 2
# 19                                           2 : 0
# 20                                           0 : 2
# 21                                           0 : 2
# 22                                           2 : 0
# 23                                           0 : 2
# 24                                           2 : 0
# 25                                           2 : 0
# 26     перенесён
# 27                                           2 : 0
# 28                                          1 : 16
# 29                                           1 : 2
# ...                                               ...
# 2844                                         2 : 0
# 2845                                         2 : 0
# 2846     отменен
# 2847                                         2 : 1
# 2848                                         2 : 0
# 2849                                         0 : 2
# 2850                                         2 : 1
# 2851                                         1 : 0
# 2852                                         0 : 2
# 2853     отменен
# 2854     отменен
# 2855                                         1 : 2
# 2856                                         2 : 0
# 2857     отменен
# 2858                                       13 : 16
# 2859                                       16 : 13
# 2860                                         2 : 0
# 2861                                       16 : 10
# 2862     отменен
# 2863                                        2 : 16
# 2864                                        16 : 9
# 2865                                       16 : 12
# 2866     отменен
# 2867                                         2 : 0
# 2868                                       13 : 16
# 2869                                         2 : 0
# 2870                                       12 : 16
# 2871                                        16 : 7
# 2872                                        16 : 8
# 2873                                       16 : 10
#
#               Right_team_title  Moneybet_for_right_team  \
# 0           Bushido Boyz null                      2438
# 1                    heX null                      3579
# 2              Prospects null                      2874
# 3             Just Swing null                      8356
# 4                   Heroic 16                    347675
# 5                Bizarre null                      2236
# 6            Team Reapers 137                     22679
# 7                SJ Gaming 61                     19816
# 8                  AVANGAR 19                     47417
# 9                  Tricked 32                     29065
# 10                    mibr 15                    336607
# 11                 OFFSET 102                     13777
# 12             Sinister5 null                      8314
# 13                    HAVU 49                     10942
# 14       Copenhagen Flames 74                     24728
# 15               SJ Gaming 61                     35031
# 16                 Tricked 32                     18493
# 17            Defusekids null                      6669
# 18              mousesports 5                    837313
# 19               Renegades 17                     78480
# 20                     Ence 6                    623690
# 21                    North 9                   1076890
# 22          Lyngby Vikings 84                     51560
# 23                 Epsilon 48                     46874
# 24                  Sharks 58                    769561
# 25               Control null                      7961
# 26               StackEm null                       671
# 27                   FURIA 13                    876072
# 28                  Isurus 73                     56349
# 29                    mibr 15                    606024
# ...                        ...                      ...
# 2844               Panda null                    357390
# 2845             Alpha Red 86                     47922
# 2846            Niknexus null                       613
# 2847                  EnVy 44                    445843
# 2848   Imperial (Brazil) null                     40009
# 2849                 FURIA 13                    159439
# 2850                 Liquid 2                    671659
# 2851                  mibr 15                    331370
# 2852                Isurus 73                     70883
# 2853                   coL 26                      2803
# 2854                  EnVy 44                      1302
# 2855                  EnVy 44                     23489
# 2856            Luminosity 36                    129871
# 2857                 Liquid 2                   1475706
# 2858                   NiP 14                    854199
# 2859                  FaZe 11                    207384
# 2860   Codewise Unicorns null                     39117
# 2861      Runtime (OwmS) null                     11039
# 2862                DETONA 77                     48091
# 2863                 Liquid 2                   1102458
# 2864                  FaZe 11                    717836
# 2865                   NiP 14                    222140
# 2866                 TDR null                       562
# 2867            Evidence null                      6514
# 2868               Apeks null                     20472
# 2869                pro100 55                     39694
# 2870      Runtime (OwmS) null                     79983
# 2871                   NiP 14                    794252
# 2872                  FaZe 11                    432651
# 2873                  mibr 15                    304121
#
#      Winning_team_match_result               Hypothesis
# 0               Первая команда        Гипотеза не верна
# 1               Первая команда           Гипотеза верна
# 2               Первая команда           Гипотеза верна
# 3               Первая команда           Гипотеза верна
# 4               Первая команда           Гипотеза верна
# 5               Вторая команда        Гипотеза не верна
# 6                 Матч отменен  Гипотеза не проверялась
# 7               Первая команда        Гипотеза не верна
# 8               Вторая команда           Гипотеза верна
# 9               Вторая команда           Гипотеза верна
# 10              Вторая команда        Гипотеза не верна
# 11              Вторая команда           Гипотеза верна
# 12              Первая команда           Гипотеза верна
# 13              Первая команда        Гипотеза не верна
# 14              Первая команда           Гипотеза верна
# 15              Вторая команда           Гипотеза верна
# 16              Вторая команда           Гипотеза верна
# 17              Первая команда           Гипотеза верна
# 18              Вторая команда        Гипотеза не верна
# 19              Первая команда           Гипотеза верна
# 20              Вторая команда           Гипотеза верна
# 21              Вторая команда           Гипотеза верна
# 22              Первая команда           Гипотеза верна
# 23              Вторая команда        Гипотеза не верна
# 24              Первая команда           Гипотеза верна
# 25              Первая команда        Гипотеза не верна
# 26              Матч перенесен  Гипотеза не проверялась
# 27              Первая команда           Гипотеза верна
# 28              Вторая команда           Гипотеза верна
# 29              Вторая команда           Гипотеза верна
# ...                        ...                      ...
# 2844            Вторая команда           Гипотеза верна
# 2845            Первая команда        Гипотеза не верна
# 2846            Первая команда           Гипотеза верна
# 2847            Первая команда           Гипотеза верна
# 2848            Первая команда           Гипотеза верна
# 2849            Первая команда           Гипотеза верна
# 2850            Вторая команда        Гипотеза не верна
# 2851              Матч отменен  Гипотеза не проверялась
# 2852            Первая команда        Гипотеза не верна
# 2853            Вторая команда           Гипотеза верна
# 2854            Вторая команда           Гипотеза верна
# 2855            Вторая команда        Гипотеза не верна
# 2856            Вторая команда           Гипотеза верна
# 2857            Первая команда           Гипотеза верна
# 2858            Первая команда        Гипотеза не верна
# 2859            Первая команда           Гипотеза верна
# 2860            Вторая команда           Гипотеза верна
# 2861            Вторая команда           Гипотеза верна
# 2862            Первая команда           Гипотеза верна
# 2863            Вторая команда        Гипотеза не верна
# 2864            Первая команда           Гипотеза верна
# 2865            Вторая команда           Гипотеза верна
# 2866            Вторая команда           Гипотеза верна
# 2867            Первая команда           Гипотеза верна
# 2868            Вторая команда        Гипотеза не верна
# 2869            Первая команда           Гипотеза верна
# 2870            Первая команда        Гипотеза не верна
# 2871            Матч перенесен  Гипотеза не проверялась
# 2872            Первая команда           Гипотеза верна
# 2873            Вторая команда           Гипотеза верна
#
# [2874 rows x 7 columns]

# %%
presentmatchs
# Out:
#          Left_team_title Left_team_coefficients  Moneybet_for_left_team  \
# 0              13 FURIA                   x1.08                  346637
# 1             128 Ignis                   x1.69                     110
# 2                 7 NRG                   x1.22                   92534
# 3             null FATE                   x1.04                    1611
# 4            48 Epsilon                   x1.70                     734
# 5              12 CR4ZY                   x1.50                   35348
# 6    54 ALTERNATE aTTaX                  x36.30                       8
# 7            32 Tricked                   x6.22                     260
# 8               49 HAVU                   x1.00                    1644
# 9        65 Izako Boars                   x1.07                     134
# 10            63 expert                  x87.27                      17
# 11         61 SJ Gaming                   x1.04                     126
# 12          88 Heretics                   x7.19                      21
# 13              9 North                   x1.02                  252788
# 14               6 Ence                   x1.17                   10508
# 15             2 Liquid                   x1.01                  254999
#
#    Left_team_win_percent Time_before_match        Right_team_title  \
# 0                    92%            1ч 46м              Sharks 58
# 1                    57%            3ч 46м          Absolute null
# 2                    80%            4ч 46м                INTZ 45
# 3                    96%            5ч 46м        HEADSHOTBG null
# 4                    56%            6ч 46м    Unicorns of Love 70
# 5                    64%            7ч 46м               Fnatic 8
# 6                     2%           10ч 16м             AVANGAR 19
# 7                    15%           10ч 16м              Nemiga 42
# 8                   100%           10ч 16м              Fierce 87
# 9                    93%           10ч 16м        Defusekids null
# 10                    1%           10ч 16м                LDLC 64
# 11                   96%           10ч 16м          BlueJays null
# 12                   13%           10ч 46м   Copenhagen Flames 74
# 13                   98%           10ч 46м          mousesports 5
# 14                   84%           13ч 16м                mibr 15
# 15                   99%           17ч 06м             Vitality 4
#
#    Right_team_coefficients  Moneybet_for_right_team Right_team_win_percent
# 0                   x10.82                    31768                     8%
# 1                    x2.18                       84                    43%
# 2                    x4.66                    22726                    20%
# 3                   x21.07                       72                     4%
# 4                    x2.15                      575                    44%
# 5                    x2.63                    19488                    36%
# 6                    x1.02                      314                    98%
# 7                    x1.16                     1511                    85%
# 8                      NaN                        0                     0%
# 9                   x13.10                       10                     7%
# 10                   x1.01                     1629                    99%
# 11                  x23.76                        5                     4%
# 12                   x1.13                      144                    87%
# 13                  x48.91                     4749                     2%
# 14                   x5.85                     1949                    16%
# 15                 x136.11                     1699                     1%

# %%
#Проверка победы первой команды в прошлых матчах
lpastmatchs = pastmatchs[['Left_team_title', 'Right_team_title', 'Winning_team_match_result',\
            'Hypothesis']].loc[pastmatchs['Hypothesis'] == "Гипотеза верна"].\
          loc[pastmatchs['Winning_team_match_result'] == "Первая команда"]
lpastmatchs
# Out:
#                Left_team_title          Right_team_title  \
# 1                 null mythic                  heX null
# 2             null Big Frames            Prospects null
# 3          null Thunder Logic           Just Swing null
# 4                  4 Vitality                 Heroic 16
# 12                100 Goliath            Sinister5 null
# 14        70 Unicorns of Love      Copenhagen Flames 74
# 17                 19 AVANGAR           Defusekids null
# 19                 4 Vitality              Renegades 17
# 22               61 SJ Gaming         Lyngby Vikings 84
# 24                    45 INTZ                 Sharks 58
# 27                      7 NRG                  FURIA 13
# 31                33 NoChance             mousesports 5
# 32                 48 Epsilon                 Unique 69
# 33               17 Renegades                    Ence 6
# 34                 4 Vitality                 Heroic 16
# 42                    15 mibr                     G2 10
# 44        70 Unicorns of Love                 Nemiga 42
# 47                  58 Sharks            Singularity 47
# 49                     43 AGO                  AVEZ 112
# 52                   13 FURIA                eUnited 29
# 54           null Dogs of War           Just Swing null
# 57                    85 paiN            Bulldozer null
# 60                    72 PACT                Tricked 32
# 61                   59 Syman              Winstrike 40
# 62                33 NoChance                  CR4ZY 12
# 63       74 Copenhagen Flames               Heretics 88
# 71                      7 NRG                 Sharks 58
# 73             47 Singularity                 Sharks 58
# 76                      7 NRG                TeamOne 60
# 78                 null Front           Just Swing null
# ...                        ...                       ...
# 2790            null ex-3DMAX                 expert 63
# 2798                34 MVP PK                 5power 80
# 2800           82 Lucid Dream                   TnC 106
# 2803             86 Alpha Red                 BOOM null
# 2805                null IPET                 5power 80
# 2808               null Panda                 IPET null
# 2810                  106 TnC                 BOOM null
# 2813                99 Beyond                 Maple 122
# 2817                 13 FURIA                eUnited 29
# 2818               29 eUnited               Denial null
# 2819         null All Knights                 DETONA 77
# 2820            null Niknexus                 DETONA 77
# 2828          null devils.one               NoChance 33
# 2830            null Niknexus          All Knights null
# 2833         null All Knights             Niknexus null
# 2835               19 AVANGAR                     G2 10
# 2838                 18 Tyloo                 ViCi null
# 2840           67 Ground Zero                 Chiefs 35
# 2843         null Storm Rider             Absolute null
# 2846                77 DETONA             Niknexus null
# 2847              null Denial                   EnVy 44
# 2848                  129 W7M    Imperial (Brazil) null
# 2849               29 eUnited                  FURIA 13
# 2857                   6 Ence                  Liquid 2
# 2859               1 Astralis                   FaZe 11
# 2862                  129 W7M                 DETONA 77
# 2864                   6 Ence                   FaZe 11
# 2867   null Imperial (Brazil)             Evidence null
# 2869       54 ALTERNATE aTTaX                 pro100 55
# 2872                 2 Liquid                   FaZe 11
#
#      Winning_team_match_result      Hypothesis
# 1               Первая команда  Гипотеза верна
# 2               Первая команда  Гипотеза верна
# 3               Первая команда  Гипотеза верна
# 4               Первая команда  Гипотеза верна
# 12              Первая команда  Гипотеза верна
# 14              Первая команда  Гипотеза верна
# 17              Первая команда  Гипотеза верна
# 19              Первая команда  Гипотеза верна
# 22              Первая команда  Гипотеза верна
# 24              Первая команда  Гипотеза верна
# 27              Первая команда  Гипотеза верна
# 31              Первая команда  Гипотеза верна
# 32              Первая команда  Гипотеза верна
# 33              Первая команда  Гипотеза верна
# 34              Первая команда  Гипотеза верна
# 42              Первая команда  Гипотеза верна
# 44              Первая команда  Гипотеза верна
# 47              Первая команда  Гипотеза верна
# 49              Первая команда  Гипотеза верна
# 52              Первая команда  Гипотеза верна
# 54              Первая команда  Гипотеза верна
# 57              Первая команда  Гипотеза верна
# 60              Первая команда  Гипотеза верна
# 61              Первая команда  Гипотеза верна
# 62              Первая команда  Гипотеза верна
# 63              Первая команда  Гипотеза верна
# 71              Первая команда  Гипотеза верна
# 73              Первая команда  Гипотеза верна
# 76              Первая команда  Гипотеза верна
# 78              Первая команда  Гипотеза верна
# ...                        ...             ...
# 2790            Первая команда  Гипотеза верна
# 2798            Первая команда  Гипотеза верна
# 2800            Первая команда  Гипотеза верна
# 2803            Первая команда  Гипотеза верна
# 2805            Первая команда  Гипотеза верна
# 2808            Первая команда  Гипотеза верна
# 2810            Первая команда  Гипотеза верна
# 2813            Первая команда  Гипотеза верна
# 2817            Первая команда  Гипотеза верна
# 2818            Первая команда  Гипотеза верна
# 2819            Первая команда  Гипотеза верна
# 2820            Первая команда  Гипотеза верна
# 2828            Первая команда  Гипотеза верна
# 2830            Первая команда  Гипотеза верна
# 2833            Первая команда  Гипотеза верна
# 2835            Первая команда  Гипотеза верна
# 2838            Первая команда  Гипотеза верна
# 2840            Первая команда  Гипотеза верна
# 2843            Первая команда  Гипотеза верна
# 2846            Первая команда  Гипотеза верна
# 2847            Первая команда  Гипотеза верна
# 2848            Первая команда  Гипотеза верна
# 2849            Первая команда  Гипотеза верна
# 2857            Первая команда  Гипотеза верна
# 2859            Первая команда  Гипотеза верна
# 2862            Первая команда  Гипотеза верна
# 2864            Первая команда  Гипотеза верна
# 2867            Первая команда  Гипотеза верна
# 2869            Первая команда  Гипотеза верна
# 2872            Первая команда  Гипотеза верна
#
# [1075 rows x 4 columns]

# %%
#Проверка победы второй команды в прошлых матчах
rpastmatchs = pastmatchs[['Left_team_title', 'Right_team_title', 'Winning_team_match_result',\
            'Hypothesis']].loc[pastmatchs['Hypothesis'] == "Гипотеза верна"].\
          loc[pastmatchs['Winning_team_match_result'] == "Вторая команда"]
rpastmatchs
# Out:
#              Left_team_title          Right_team_title  \
# 7                   14 mibr                      G2 9
# 15            36 Luminosity                  FURIA 13
# 18               59 TeamOne            Singularity 47
# 20           135 Red Canids                   paiN 85
# 27              33 NoChance                  CR4ZY 12
# 28     74 Copenhagen Flames               Heretics 88
# 36                    6 NRG                 Sharks 60
# 44         null Dogs of War         Good Game PR null
# 47                77 DETONA                 Isurus 73
# 49                 null EOX                   W7M 130
# 56                  72 PACT                 Fierce 87
# 57               32 Tricked              Illuminar 66
# 65             66 Illuminar         Chaos (Sweden) 50
# 73             133 Malvinas            Sinisters null
# 76                 2 Liquid                 Cloud9 53
# 78                  49 HAVU                   Vega 51
# 85                  14 mibr                     NRG 6
# 86                  11 FaZe                  Liquid 2
# 95                 2 Liquid                     NRG 6
# 103                 11 FaZe                     NRG 6
# 106               25 Spirit            Singularity 47
# 108              98 Furious            Sinisters null
# 115            61 SJ Gaming              Turkey5 null
# 116                   41 VP                Epsilon 48
# 125         null Just Swing     absolute mad lads 125
# 133               87 Fierce              SJ Gaming 61
# 136            66 Illuminar            Aristocracy 39
# 138     null madlikewizards               Justice 139
# 145              null Artyk               NONAME null
# 146                 51 Vega            DreamEaters 52
# ...                      ...                       ...
# 1595      50 Chaos (Sweden)                 Nemiga 42
# 1596             48 Epsilon                  x-kom 46
# 1605               116 Jade                    SYF 81
# 1613           16 Renegades                    coL 26
# 1616                130 W7M          Team Reapers 138
# 1618         135 Red Canids                Santos 142
# 1632                72 PACT    Codewise Unicorns null
# 1640            139 Justice                Genuine 89
# 1643         82 Lucid Dream                 MVP PK 34
# 1645        null Cloud9 old             Luminosity 36
# 1652         47 Singularity                   mibr 14
# 1653              77 DETONA             Evidence null
# 1662               22 forZe                AVANGAR 19
# 1670                 71 ATK               ex-Zone 117
# 1673                 44 AGO              Winstrike 40
# 1675           40 Winstrike                 Sprout 21
# 1682         null Ghost old                  FURIA 13
# 1683   74 Copenhagen Flames          GoldenGitte null
# 1691                 15 NiP                   Na'Vi 3
# 1699                 15 NiP               Giants null
# 1702           40 Winstrike                    AGO 44
# 1704              34 MVP PK                  Tyloo 18
# 1711             98 Furious         PELAFUSTANES null
# 1712                130 W7M          ex-Imperial null
# 1721                 26 coL                    ATK 71
# 1729     37 Movistar Riders               Giants null
# 1732             19 AVANGAR            HellRaisers 23
# 1734              34 MVP PK                BOOT-dS 68
# 1741                43 INTZ                    ATK 71
# 1742               13 FURIA         Bad News Bears 79
#
#      Winning_team_match_result      Hypothesis
# 7               Вторая команда  Гипотеза верна
# 15              Вторая команда  Гипотеза верна
# 18              Вторая команда  Гипотеза верна
# 20              Вторая команда  Гипотеза верна
# 27              Вторая команда  Гипотеза верна
# 28              Вторая команда  Гипотеза верна
# 36              Вторая команда  Гипотеза верна
# 44              Вторая команда  Гипотеза верна
# 47              Вторая команда  Гипотеза верна
# 49              Вторая команда  Гипотеза верна
# 56              Вторая команда  Гипотеза верна
# 57              Вторая команда  Гипотеза верна
# 65              Вторая команда  Гипотеза верна
# 73              Вторая команда  Гипотеза верна
# 76              Вторая команда  Гипотеза верна
# 78              Вторая команда  Гипотеза верна
# 85              Вторая команда  Гипотеза верна
# 86              Вторая команда  Гипотеза верна
# 95              Вторая команда  Гипотеза верна
# 103             Вторая команда  Гипотеза верна
# 106             Вторая команда  Гипотеза верна
# 108             Вторая команда  Гипотеза верна
# 115             Вторая команда  Гипотеза верна
# 116             Вторая команда  Гипотеза верна
# 125             Вторая команда  Гипотеза верна
# 133             Вторая команда  Гипотеза верна
# 136             Вторая команда  Гипотеза верна
# 138             Вторая команда  Гипотеза верна
# 145             Вторая команда  Гипотеза верна
# 146             Вторая команда  Гипотеза верна
# ...                        ...             ...
# 1595            Вторая команда  Гипотеза верна
# 1596            Вторая команда  Гипотеза верна
# 1605            Вторая команда  Гипотеза верна
# 1613            Вторая команда  Гипотеза верна
# 1616            Вторая команда  Гипотеза верна
# 1618            Вторая команда  Гипотеза верна
# 1632            Вторая команда  Гипотеза верна
# 1640            Вторая команда  Гипотеза верна
# 1643            Вторая команда  Гипотеза верна
# 1645            Вторая команда  Гипотеза верна
# 1652            Вторая команда  Гипотеза верна
# 1653            Вторая команда  Гипотеза верна
# 1662            Вторая команда  Гипотеза верна
# 1670            Вторая команда  Гипотеза верна
# 1673            Вторая команда  Гипотеза верна
# 1675            Вторая команда  Гипотеза верна
# 1682            Вторая команда  Гипотеза верна
# 1683            Вторая команда  Гипотеза верна
# 1691            Вторая команда  Гипотеза верна
# 1699            Вторая команда  Гипотеза верна
# 1702            Вторая команда  Гипотеза верна
# 1704            Вторая команда  Гипотеза верна
# 1711            Вторая команда  Гипотеза верна
# 1712            Вторая команда  Гипотеза верна
# 1721            Вторая команда  Гипотеза верна
# 1729            Вторая команда  Гипотеза верна
# 1732            Вторая команда  Гипотеза верна
# 1734            Вторая команда  Гипотеза верна
# 1741            Вторая команда  Гипотеза верна
# 1742            Вторая команда  Гипотеза верна
#
# [335 rows x 4 columns]

# %%
#Проверка первой команды в текущих матчах
lpresentmatchs = presentmatchs[['Left_team_title', 'Right_team_title',\
               'Moneybet_for_left_team', 'Moneybet_for_right_team']].\
             loc[presentmatchs['Moneybet_for_left_team'] > presentmatchs['Moneybet_for_right_team']]
lpresentmatchs
# Out:
#   Left_team_title     Right_team_title  Moneybet_for_left_team  \
# 4       2 Liquid                 G2 9                   189922
# 5        43 INTZ            Sharks 60                     2363
# 6          6 NRG             FURIA 13                     4903
# 7   61 SJ Gaming    Lyngby Vikings 84                        5
# 8       12 CR4ZY             TBD null                      182
# 9    101 Goliath       Sinister5 null                      267
#
#    Moneybet_for_right_team
# 4                    36846
# 5                      464
# 6                     4079
# 7                        0
# 8                       11
# 9                      176

# %%
#Проверка второй команды в текущих матчах
rpresentmatchs = presentmatchs[['Left_team_title', 'Right_team_title',\
               'Moneybet_for_left_team', 'Moneybet_for_right_team']].\
             loc[presentmatchs['Moneybet_for_left_team'] < presentmatchs['Moneybet_for_right_team']]
rpresentmatchs
# Out:
#       Left_team_title Right_team_title  Moneybet_for_left_team  \
# 0        33 NoChance    mousesports 5                   123616
# 1       16 Renegades           Ence 7                    57730
# 2            45 EnVy          mibr 14                    31153
# 3   138 Team Reapers        Isurus 73                    10780
#
#    Moneybet_for_right_team
# 0                   782678
# 1                   161609
# 2                    89092
# 3                    15788

# %%
lipresentmatchs = lpresentmatchs['Left_team_title']
lipresentmatchs
# Out:
# 4         2 Liquid
# 5          43 INTZ
# 6            6 NRG
# 7     61 SJ Gaming
# 8         12 CR4ZY
# 9      101 Goliath
# Name: Left_team_title, dtype: object

# %%
ripresentmatchs = rpresentmatchs['Right_team_title']
ripresentmatchs
# Out:
# 0     mousesports 5
# 1            Ence 7
# 2           mibr 14
# 3         Isurus 73
# Name: Right_team_title, dtype: object

# %%
top_teams = []
for lprmatch in list(lipresentmatchs):
    if (lprmatch in list(lpastmatchs['Left_team_title'])) and ((list(lpastmatchs['Hypothesis']).count('Гипотеза верна')) >=3)\
    or lprmatch in list(rpastmatchs['Right_team_title']) and ((list(lpastmatchs['Hypothesis']).count('Гипотеза верна')) >=3):
        print(lprmatch)
        top_teams.append(lprmatch)
# Out:
#  2 Liquid
#  43 INTZ
#  6 NRG
#  61 SJ Gaming
#  12 CR4ZY
#  101 Goliath

# %%
top_teams_coloured = []
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
for rprmatch in list(ripresentmatchs):
    if (rprmatch in list(lpastmatchs['Left_team_title'])) and ((list(lpastmatchs['Hypothesis']).count('Гипотеза верна')) >=3)\
    or rprmatch in list(rpastmatchs['Right_team_title']) and ((list(lpastmatchs['Hypothesis']).count('Гипотеза верна')) >=3):
        print(rprmatch)
        top_teams.append(rprmatch)
for team in top_teams:
    top_teams_coloured.append(color.RED + color.BOLD + team + color.END)

print(top_teams_coloured)
# Out:
#  mousesports 5
#  Ence 7
#  mibr 14
#  Isurus 73
# ['\x1b\x1b 2 Liquid \x1b', '\x1b\x1b 43 INTZ \x1b', '\x1b\x1b 6 NRG \x1b', '\x1b\x1b 61 SJ Gaming \x1b', '\x1b\x1b 12 CR4ZY \x1b', '\x1b\x1b 101 Goliath \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b', '\x1b\x1b mousesports 5 \x1b', '\x1b\x1b Ence 7 \x1b', '\x1b\x1b mibr 14 \x1b', '\x1b\x1b Isurus 73 \x1b']

# %%
list(lpastmatchs['Hypothesis']).count('Гипотеза верна') >=3
# Out:
# 689

# %%
presentmatchs
# Out:
#        Left_team_title Left_team_coefficients  Moneybet_for_left_team  \
# 0         33 NoChance                   x6.70                  123616
# 1        16 Renegades                   x3.52                   57730
# 2             45 EnVy                   x3.57                   31153
# 3    138 Team Reapers                   x2.32                   10780
# 4            2 Liquid                   x1.17                  189922
# 5             43 INTZ                   x1.18                    2363
# 6               6 NRG                   x1.75                    4903
# 7        61 SJ Gaming                   x1.00                       5
# 8            12 CR4ZY                   x1.05                     182
# 9         101 Goliath                   x1.59                     267
# 10         null EXILE                   x1.00                       0
#
#    Left_team_win_percent Time_before_match     Right_team_title  \
# 0                    14%      Скоро старт        mousesports 5
# 1                    26%      Скоро старт               Ence 7
# 2                    26%               20м             mibr 14
# 3                    41%            1ч 00м           Isurus 73
# 4                    84%            2ч 40м                G2 9
# 5                    84%           11ч 00м           Sharks 60
# 6                    55%           14ч 00м            FURIA 13
# 7                   100%           16ч 00м   Lyngby Vikings 84
# 8                    94%           17ч 00м            TBD null
# 9                    60%           21ч 30м      Sinister5 null
# 10                    0%           21ч 30м            TBD null
#
#    Right_team_coefficients  Moneybet_for_right_team Right_team_win_percent
# 0                    x1.14                   782678                    14%
# 1                    x1.32                   161609                    26%
# 2                    x1.31                    89092                    26%
# 3                    x1.61                    15788                    41%
# 4                    x5.64                    36846                    84%
# 5                    x5.59                      464                    84%
# 6                    x2.08                     4079                    55%
# 7                      NaN                        0                   100%
# 8                   x15.89                       11                    94%
# 9                    x2.36                      176                    60%
# 10                   x1.00                        0                     0%
